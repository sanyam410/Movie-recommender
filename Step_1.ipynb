# %%
import pandas as pd
import numpy as np
# %pip install sentence_transformers
from sentence_transformers import SentenceTransformer
# Out:
# Requirement already satisfied: sentence_transformers in D:\data backup\Program Files\Python311\Lib\site-packages (6.0.0)
# Requirement already satisfied: transformers<6.0.0,>=5.0.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (5.16.1)
# Requirement already satisfied: tokenizers>=0.19 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (0.23.1)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.3.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (1.29.0)
# Requirement already satisfied: torch>=2.2 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (2.13.0)
# Requirement already satisfied: numpy>=1.24.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (2.4.6)
# Requirement already satisfied: scikit-learn>=1.1.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.10.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (4.16.0)
# Requirement already satisfied: tqdm>=4.0.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from sentence_transformers) (4.70.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in D:\data backup\Program Files\Python311\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (3.32.4)
# Requirement already satisfied: fsspec>=2023.5.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in D:\data backup\Program Files\Python311\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in D:\data backup\Program Files\Python311\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in D:\data backup\Program Files\Python311\Lib\site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (6.0.3)
# Requirement already satisfied: anyio in D:\data backup\Program Files\Python311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (4.14.2)
# Requirement already satisfied: certifi in D:\data backup\Program Files\Python311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in D:\data backup\Program Files\Python311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (1.0.9)
# Requirement already satisfied: idna in D:\data backup\Program Files\Python311\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in D:\data backup\Program Files\Python311\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.3.0->sentence_transformers) (0.16.0)
# Requirement already satisfied: regex>=2025.10.22 in D:\data backup\Program Files\Python311\Lib\site-packages (from transformers<6.0.0,>=5.0.0->sentence_transformers) (2026.7.19)
# Requirement already satisfied: typer in D:\data backup\Program Files\Python311\Lib\site-packages (from transformers<6.0.0,>=5.0.0->sentence_transformers) (0.27.2)
# Requirement already satisfied: safetensors>=0.8.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from transformers<6.0.0,>=5.0.0->sentence_transformers) (0.8.0)
# Requirement already satisfied: joblib>=1.4.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from scikit-learn>=1.1.0->sentence_transformers) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in D:\data backup\Program Files\Python311\Lib\site-packages (from scikit-learn>=1.1.0->sentence_transformers) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from scikit-learn>=1.1.0->sentence_transformers) (3.6.0)
# Requirement already satisfied: setuptools>=77.0.3 in D:\data backup\Program Files\Python311\Lib\site-packages (from torch>=2.2->sentence_transformers) (84.0.0)
# Requirement already satisfied: sympy>=1.13.3 in D:\data backup\Program Files\Python311\Lib\site-packages (from torch>=2.2->sentence_transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in D:\data backup\Program Files\Python311\Lib\site-packages (from torch>=2.2->sentence_transformers) (3.6.1)
# Requirement already satisfied: jinja2 in D:\data backup\Program Files\Python311\Lib\site-packages (from torch>=2.2->sentence_transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from sympy>=1.13.3->torch>=2.2->sentence_transformers) (1.3.0)
# Requirement already satisfied: colorama in D:\data backup\Program Files\Python311\Lib\site-packages (from tqdm>=4.0.0->sentence_transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from jinja2->torch>=2.2->sentence_transformers) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from typer->transformers<6.0.0,>=5.0.0->sentence_transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from typer->transformers<6.0.0,>=5.0.0->sentence_transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in D:\data backup\Program Files\Python311\Lib\site-packages (from typer->transformers<6.0.0,>=5.0.0->sentence_transformers) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence_transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in D:\data backup\Program Files\Python311\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence_transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in D:\data backup\Program Files\Python311\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=5.0.0->sentence_transformers) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv(r"C:\Users\Asus\Downloads\Jupiter Py Pro\IMDB Project\ML- Layer\Step 0- Cleaning\Clean_Data.csv")
print(f"Loaded {len(df)} Movies")
# Out:
# Loaded 4650 Movies

# %%
model = SentenceTransformer("all-MiniLM-L6-v2") 
embeddings=model.encode(df['plot'].tolist(),show_progress_bar=True)
print(embeddings.shape)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Batches:   0%|          | 0/146 [00:00<?, ?it/s]
# (4650, 384)

# %%
np.save("movie_embeddings.npy", embeddings)
print("Saved embeddings")
# Out:
# Saved embeddings

# %%
assert embeddings.shape[0] == len(df)
